# %% [markdown]
# <a href="https://colab.research.google.com/github/Sankar-A06/Machine-Learning/blob/main/Asssignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment-3

# %% [markdown]
# #1.Basic Line Plot
# Plot a simple line graph of 𝑦=𝑥^2 for 𝑥 values ranging from -10 to 10.
#
# Label the x-axis as "X Values" and the y-axis as "Squared Values."
#
# Add a title to the graph.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Define x values and calculate y values
x = np.linspace(-10, 10, 100)
y = x**2

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="y = x^2", color="blue")

# Label the axes and add a title
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Line Plot of y = x^2")

# Show the plot
plt.legend()
print("Here,It is a parabola")
print()
plt.show()
# Out:
# Here,It is a parabola

# %% [markdown]
# # 2.Bar graph
#
# Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi',
#
# 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88]. o Add labels
#
# to the x-axis and y-axis and give the chart a title.

# %%
import numpy as np
students = np.array(['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita'])#students array
marks = np.array([85, 90, 78, 92, 88])#marks array
plt.bar(students, marks)#bar method calling
plt.xlabel('Students')#set x-axis
plt.ylabel('Marks')#set y-axis
plt.title('Marks of 5 Students')
plt.show()#showing the bar graph

# %% [markdown]
# # 3.Scatter Plot
# Generate two lists of 20 random integers each (for x and y coordinates).
#
# Create a scatter plot with these values, and customize it by adding color,size, and labels to the points.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate two lists of 20 random integers each for x and y coordinates
np.random.seed(42)  # For reproducibility
x = np.random.randint(1, 101, 20)
y = np.random.randint(1, 101, 20)

# Generate random colors and sizes for the points
colors = np.random.rand(20)
sizes = np.random.randint(50, 300, 20)

# Create a scatter plot
plt.figure(figsize=(8, 6))
z= plt.scatter(x, y, c=colors, s=sizes, alpha=0.8, cmap='viridis', edgecolor='black')

# Add labels and title
plt.xlabel("X Coordinates")
plt.ylabel("Y Coordinates")
plt.title("Customized Scatter Plot")

# Show color bar for the colors
plt.colorbar(z, label="Color Scale")

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # 4.Histogram
# Simulate 100 random values from a normal distribution using np.random.randn() and plot a histogram. o Customize the number of bins and add a grid to the plot.

# %%
data=np.random.randn(100)
plt.hist(data, edgecolor='black')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Histogram of 100 random values')
plt.show()

# %% [markdown]
# o Customize the number of bins and add a grid to the plot.

# %%
data = np.random.randn(100)
plt.hist(data, bins=20, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 100 Random Values from a Normal Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# # 5.Pie Chart
# Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E'] with values [20, 30, 25, 15, 10].
# o	Display the percentage values on the chart and use a color palette for differentiation.

# %%
data = {'A':20, 'B':30, 'C':25, 'D':15, 'E':10}
labels = list(data.keys())
values = list(data.values())
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # 6.Box Plot (Seaborn)
# Create a box plot to visualize the distribution of the marks scored by students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]. o Highlight the median and any outliers.

# %%
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]
sns.boxplot(data=marks)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.title('Box Plot of Marks Scored by Students in a class')
# Display the plot
plt.show()

# %% [markdown]
# Highlight the median and any outliers

# %%
marks = [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]

sns.boxplot(data=marks)

median = np.median(marks)
plt.axhline(median, color='g', linestyle='--', label='Median')

plt.xlabel('Students')
plt.ylabel('Marks')
plt.title('Box Plot of Marks Scored by Students')

plt.legend()
plt.show()

# %% [markdown]
# # 7.Heatmap (Seaborn)
# Create a 5x5 matrix with random integers between 1 and 10 using np.random.randint() and visualize it as a heatmap using Seaborn. o Add a color bar and annotate the heatmap with the values.

# %%
import seaborn as scn
matrix = np.random.randint(1,10,size=(6,6))
scn.heatmap(matrix)
# Out:
# <Axes: >

# %% [markdown]
# Add a color bar and annotate the heatmap with the values.

# %%
matrix = np.random.randint(1,10,size=(6,6))
scn.heatmap(matrix, annot=True, cmap='viridis')
scn.heatmap(matrix)
# Out:
# <Axes: >

# %% [markdown]
# # 8.
# Comparison of Matplotlib and Seaborn o Generate a pair of plots (barcharts or line plots) using the same data in both Matplotlib and Seaborn Highlight the differences in the code, syntax, and aesthetics of the two
# libraries.

# %%
import matplotlib.pyplot as plt
categories = ['A', 'B', 'C', 'D', 'E']
values = [20, 30, 25, 15, 10]
plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart using Matplotlib')
# Display the plot
plt.show()

# %% [markdown]
# #Difference in code , Aesthitics and syntax

# %% [markdown]
# #Code and Syntax:
# Matplotlib: The code is more straightforward and requires fewer imports. You directly use the plt.bar() function to create the bar chart.
#
# **Seaborn**: You need to create a DataFrame to use Seaborn effectively. The sns.barplot() function is used, and you pass the DataFrame along with the column names for the x and y axes.
#
# #Aesthetics:
# ***Matplotlib***: The default aesthetics are simpler and more basic. Customization requires more manual adjustments.
#
# ***Seaborn***: The default aesthetics are more polished and visually appealing. Seaborn automatically applies a more sophisticated style to the plots.

# %% [markdown]
# # 9.Pair Plot (Seaborn)
# Manually create a small dataset with columns such
# as 'Age', 'Height','Weight' for 10 individuals and visualize the relationships using a pair
#
#  plot.

# %%
import pandas as pd
data = {
    'Age': [23, 25, 22, 24, 26, 28, 30, 21, 27, 29],
    'Height': [165, 170, 160, 175, 168, 172, 180, 158, 176, 169],
    'Weight': [60, 65, 55, 70, 62, 68, 75, 54, 72, 66]
}
df = pd.DataFrame(data)
sns.pairplot(df)
# plot
plt.suptitle('Pair Plot of Age, Height, and Weight', y=1.02)
# Display the plot
plt.show()

# %% [markdown]
# # 10.	Save and Style Plots
#
# •	Plot any graph of your choice and save it in both .png and .pdf formats.
#
# •	Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid')
#
# and explain how the style impacts the visualization.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Apply the 'ggplot' style
plt.style.use('ggplot')

# Generate x values
x = np.linspace(0, 10, 100)

# Compute y values
y = np.sin(x)

# Create the plot
plt.plot(x, y, label='sin(x)')

# Customize the plot
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Plot of sin(x)')
plt.legend()

# Save the plot in .png and .pdf formats
plt.savefig('plot.png')
plt.savefig('plot.pdf')

# Display the plot
plt.show()

# %% [markdown]
# ### The **'ggplot'** style is inspired by the aesthetics of the ggplot2 package in R.
#
# It provides a clean and modern look to the plots with grid lines, a light gray background, polished font and line styles, and a vibrant color palette.
