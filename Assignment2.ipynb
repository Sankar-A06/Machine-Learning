# %% [markdown]
# <a href="https://colab.research.google.com/github/Sankar-A06/Machine-Learning/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Asssignment 2

# %% [markdown]
# 1.Create a Pandas DataFrame from the following dictionary:
#
# data = {
#
# 'Name': ['Alice', 'Bob', 'Carol'],
#
# 'Age': [24, 27, 22],
#
# 'Salary': [50000, 55000, 48000]
#
# }
#
# • Add a new column called Bonus which is 10% of the salary.

# %%
import numpy as np
import pandas as pd
data = {
    'Name':['Alice','Bob','Carol'],
    'Age':[24,27,22],
    'Salary':[50000,55000,48000]
}
df = pd.DataFrame(data)
print(df)
df['Bonus']=df['Salary']*0.1
print("After adding the column it becomes")
df
# Out:
#     Name  Age  Salary
# 0  Alice   24   50000
# 1    Bob   27   55000
# 2  Carol   22   48000
# After adding the column it becomes
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# 2.Given the DataFrame created in the above question:
#
# • Display the first two rows.
#
# • Compute the mean salary.

# %%
#Display the first two rows.
print(df)
print("First two rows:-")
df.head(2)
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0
# First two rows:-
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0

# %%
#Compute the mean salary.
print(df)
print("Mean salary:-")
df['Salary'].mean()
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0
# Mean salary:-
# 51000.0

# %% [markdown]
# 3.Using the same DataFrame:
#
# • Extract all rows where the Age is greater than 25.
#
# • Filter out rows where the Salary is less than 50000.

# %%
#Extracting all rows where the Age is greater than 25.
print(df)
print("Rows where the Age is greater than 25:-")
df[df['Age']>25]
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0
# Rows where the Age is greater than 25:-
#   Name  Age  Salary   Bonus
# 1  Bob   27   55000  5500.0

# %%
#Filter out rows where the Salary is less than 50000.
print(df)
print("Rows where the Salary is less than 50000:-")
df[df['Salary']>=50000]
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0
# Rows where the Salary is less than 50000:-
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0

# %% [markdown]
# 4.Create the following DataFrame:
#
# data = {
#
# 'A': [1, 2, None, 4],
#
# 'B': [None, 2, 3, None],
#
# 'C': [1, 2, 3, 4]
# }
#
# df = pd.DataFrame(data)
#
# • Fill missing values in column A with the mean of the column.
#
# • Drop rows where all values are None.

# %%
data = {
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, None],
    'C': [1, 2, 3, 4]
}
df = pd.DataFrame(data)
print(df)
mean = df['A'].mean()
df['A'].fillna(mean,inplace=True)
print("After filling the missing values in column A with mean:-")
print(df)
df.dropna(axis=0,how='all',inplace=True)
print("After dropping the rows where all values are None:-")
print(df)
# Out:
#      A    B  C
# 0  1.0  NaN  1
# 1  2.0  2.0  2
# 2  NaN  3.0  3
# 3  4.0  NaN  4
# After filling the missing values in column A with mean:-
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4
# After dropping the rows where all values are None:-
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4
# <ipython-input-41-86fa058cef91>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(mean,inplace=True)

# %% [markdown]
# 5.Create a DataFrame for employees:
#
# data = {
#
# 'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
#
# 'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
#
# 'Salary': [50000, 45000, 60000, 65000, 70000]
#
# }
#
# • Group the data by Department and compute the total and mean salary for each
#
# department.

# %%
data = {

'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],

'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],

'Salary': [50000, 45000, 60000, 65000, 70000]

}
df=pd.DataFrame(data)
print(df)
df1=df.groupby('Department')
print("Total and mean salary for each department:-")
df1.agg({'Salary':['sum','mean']})
# Out:
#   Department Employee  Salary
# 0         HR    Alice   50000
# 1         HR      Bob   45000
# 2         IT    Carol   60000
# 3         IT    David   65000
# 4    Finance      Eve   70000
# Total and mean salary for each department:-
#             Salary
#                sum     mean
# Department
# Finance      70000  70000.0
# HR           95000  47500.0
# IT          125000  62500.0

# %% [markdown]
# 6.Given two DataFrames:
#
# df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
#
# df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
#
# • Perform an inner join on the ID column

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
print(df1)
print(df2)
df3=pd.merge(df1,df2,on='ID',how='inner')
print("After performing the inner join:-")
df3
# Out:
#    ID   Name
# 0   1  Alice
# 1   2    Bob
# 2   3  Carol
#    ID  Age
# 0   2   25
# 1   3   30
# 2   4   22
# After performing the inner join:-
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# 7.Given a small dataset, clean and display basic statistics using Pandas.

# %%
data = {
 'Department': ['Cse', 'Cse', 'Ece', 'Ece', 'Aids'],
 'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
 'Salary': [50000, 45000, 60000, 65000, 70000]
}
df = pd.DataFrame(data)
print(df.describe())
# Out:
#              Salary
# count      5.000000
# mean   58000.000000
# std    10368.220677
# min    45000.000000
# 25%    50000.000000
# 50%    60000.000000
# 75%    65000.000000
# max    70000.000000

# %% [markdown]
# 8.small EDA task
#
# • Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
#
# • Perform the following tasks:
#
# o Display the number of missing values in each column.
#
# o Find the average age of passengers.
#
# o Create a bar plot to show the survival rate based on gender

# %%
#Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
Titanic = pd.read_csv('/content/Titanic-Dataset.csv')
#Display the number of missing values in each column.
missing_values = Titanic.isnull().sum()
print(missing_values)
#Find the average age of passengers
mean_age = Titanic["Age"].mean()
print(mean_age)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# 29.69911764705882

# %%
#Create a bar plot to show the survival rate based on gender
import matplotlib.pyplot as plt
sur_rate = Titanic.groupby('Sex')['Survived'].mean()
sur_rate.plot(kind='bar',color = "#603")
plt.show()

# %% [markdown]
# Load a dataset containing daily temperatures and dates

# %%
data = {
    'Date': ['2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04', '2024-12-05'],
    'Temperature': [22, 25, 19, 30, 18]
}
# Created DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# Convert the date column into a DateTime object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# Create a new column that categorizes temperatures into High, Medium, or Low.

# %%
def Temperature_Category(temp):
    if temp >= 25:
        return 'High'
    elif temp >= 20:
        return 'Medium'
    else:
        return 'Low'

df['Temperature_Category'] = df['Temperature'].apply(Temperature_Category)
# Display the transformed DataFrame
print(df)
# Out:
#         Date  Temperature Temperature_Category
# 0 2024-12-01           22               Medium
# 1 2024-12-02           25                 High
# 2 2024-12-03           19                  Low
# 3 2024-12-04           30                 High
# 4 2024-12-05           18                  Low
